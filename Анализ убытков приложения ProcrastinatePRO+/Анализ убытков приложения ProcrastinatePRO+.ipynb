# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Нижний-регистр" data-toc-modified-id="Нижний-регистр-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Нижний регистр</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Замена типа данных</a></span></li><li><span><a href="#Выявление-неявных-дубликатов" data-toc-modified-id="Выявление-неявных-дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выявление неявных дубликатов</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии" data-toc-modified-id="Функция-для-расчёта-конверсии-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для расчёта конверсии</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI</a></span></li><li><span><a href="#Функция-для-расчёта-удержания" data-toc-modified-id="Функция-для-расчёта-удержания-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Функция для расчёта удержания</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей." data-toc-modified-id="Профили-пользователей.-Определение-минимальной-и-максимальной-даты-привлечения-пользователей.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Профили пользователей. Определение минимальной и максимальной даты привлечения пользователей.</a></span></li><li><span><a href="#Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?" data-toc-modified-id="Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?</a></span></li><li><span><a href="#Какими-устройствами-они-пользуются?-С-каких-устройств-чаще-всего-заходят-платящие-пользователи?" data-toc-modified-id="Какими-устройствами-они-пользуются?-С-каких-устройств-чаще-всего-заходят-платящие-пользователи?-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?</a></span></li><li><span><a href="#По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?" data-toc-modified-id="По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Общая-сумма-расходов--на-маркетинг" data-toc-modified-id="Общая-сумма-расходов--на-маркетинг-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Общая сумма расходов  на маркетинг</a></span></li><li><span><a href="#Как-траты-распределены-по-источникам" data-toc-modified-id="Как-траты-распределены-по-источникам-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Как траты распределены по источникам</a></span></li><li><span><a href="#Визуализация-изменений-метрик-во-времени" data-toc-modified-id="Визуализация-изменений-метрик-во-времени-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Визуализация изменений метрик во времени</a></span></li><li><span><a href="#Сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника?" data-toc-modified-id="Сколько-в-среднем-стоило-привлечение-одного-покупателя-из-каждого-источника?-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Сколько в среднем стоило привлечение одного покупателя из каждого источника?</a></span></li><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Промежуточные-итоги" data-toc-modified-id="Промежуточные-итоги-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Промежуточные итоги</a></span></li><li><span><a href="#Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам" data-toc-modified-id="Графики-конверсии-и-удержания-с-разбивкой-по-устройствам,-странам,-рекламным-каналам-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам</a></span></li><li><span><a href="#Ответы-на-вопросы" data-toc-modified-id="Ответы-на-вопросы-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Ответы на вопросы</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта:**
#
# Развлекательное приложение несколько прошлых месяцев постоянно несло убытки. В привлечение пользователей было вложено много денег, но окупаемости нет.
#
# **Цель работы:**
#
# Разобраться в причинах убытка и дать рекомендации отделу маркетинга как компании выйти в плюс.
#
# **Задачи работы:**
# - Загрузить данные и подготовить их к анализу,
# - Задать функции для расчета и анализа LTV, ROI, удержания и конверсии,
# - Провести исследовательский анализ данных,
# - Расчитать расходы на маркетинг,
# - Оцените окупаемость рекламы,
# - Оценить какие факторы отрицательно влияют на привлечение пользователей.
#
# **План анализа данных**
# 1. Обзор данных и их подготовка:
# - Загрузка таблиц и их первичный обзор
# - Замена типов данных, проверка на наличие дубликатов и пропусков в таблице.
# 2. Функции для расчета и анализа LTV, ROI, удержания и конверсии:
# - задать нужные фннкции для дальнейшего анализа данных
# 3. Исследовательский анализ данных:
# - Построить профили пользователей.
# - Определить минимальную и максимальную дату привлечения пользователей.
# - Выяснить из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Выяснить какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - Выяснить по каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?
# 4. Маркетинг:
# - Выяснить сколько денег потратили? Всего / на каждый источник / по времени
# - Выяснить сколько в среднем стоило привлечение одного покупателя из каждого источника?
# 5. Оценить окупаемость рекламы
# - Используя графики LTV, ROI и CAC, проанализировать окупаемость рекламы с разбивкой по устройствам, странам, рекламным каналам
# - Построить и изучить графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам
#
# **Описание данных**
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Перед началом работы загрузим нужные нам библиотеки для работы

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# Загрузим данные о визитах, заказах и расходах и положим их в перемннные visits,orders,costs

# %%
visits, orders, costs = (
    pd.read_csv('/datasets/visits_info_short.csv'),  
    pd.read_csv('/datasets/orders_info_short.csv'),  
    pd.read_csv('/datasets/costs_info_short.csv'))

# %% [markdown]
# Посмотрим общую информацию о ДатаФреймах

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# User Id          309901 non-null int64
# Region           309901 non-null object
# Device           309901 non-null object
# Channel          309901 non-null object
# Session Start    309901 non-null object
# Session End      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# User Id     40212 non-null int64
# Event Dt    40212 non-null object
# Revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# Channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# Убедимся в отсутсвии пропусков в таблицах

# %%
visits.isna().sum()
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64

# %%
costs.isna().sum()
# Out:
# dt         0
# Channel    0
# costs      0
# dtype: int64

# %% [markdown]
# Посмотрим есть ли явные дубликаты а столбцах

# %%
visits.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
costs.duplicated().sum()
# Out:
# 0

# %%
print()

# %% [markdown]
# ###  Промежуточные выводы

# %% [markdown]
# Исходя из первичного аналдиза можно сказать, что в названии столбцов используются заглавные буквы, а так же не применется 'Snake_case'. В таблицах пропусков нет.В таблице visits в столбцах Session Start и Session End , в таблице orders в столбце Event Dt, в таблице costs в столбце dt неверно указан тип данных.
# Приведем все в порядок и далее прододжим первичный анализ данных в таблицах.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ###  Нижний регистр

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %%
visits = visits.rename(columns={'user id': 'user_id', 'session start': 'session_start', 'session end': 'session_end'})
orders = orders.rename(columns={'user id': 'user_id', 'event dt': 'event_dt'})

# %% [markdown]
# Проверим, поменялись ли названия

# %%
visits.info()
print()
orders.info()
print()
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
# user_id          309901 non-null int64
# region           309901 non-null object
# device           309901 non-null object
# channel          309901 non-null object
# session_start    309901 non-null object
# session_end      309901 non-null object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
# user_id     40212 non-null int64
# event_dt    40212 non-null object
# revenue     40212 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
# dt         1800 non-null object
# channel    1800 non-null object
# costs      1800 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ### Замена типа данных

# %% [markdown]
# Преобразуем данные о времени

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_start'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
display(visits.head(), orders.head(), costs.head())
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#           session_end
# 0 2019-05-01 02:36:01
# 1 2019-05-01 04:46:31
# 2 2019-05-01 14:09:25
# 3 2019-05-01 00:29:59
# 4 2019-05-01 03:33:35
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# ...

# %% [markdown]
# ### Выявление неявных дубликатов

# %% [markdown]
# Посмотрим уникальные значения в стобцах с строковым типом данных.

# %%
visits['region'].value_counts()
# Out:
# United States    207327
# UK                36419
# France            35396
# Germany           30759
# Name: region, dtype: int64

# %%
visits['device'].value_counts()
# Out:
# iPhone     112603
# Android     72590
# PC          62686
# Mac         62022
# Name: device, dtype: int64

# %%
visits['channel'].value_counts()
# Out:
# organic               107760
# TipTop                 54794
# FaceBoom               49022
# WahooNetBanner         20465
# LeapBob                17013
# OppleCreativeMedia     16794
# RocketSuperAds         12724
# YRabbit                 9053
# MediaTornado            8878
# AdNonSense              6891
# lambdaMediaAds          6507
# Name: channel, dtype: int64

# %%
costs['channel'].value_counts()
# Out:
# TipTop                180
# MediaTornado          180
# YRabbit               180
# OppleCreativeMedia    180
# LeapBob               180
# lambdaMediaAds        180
# WahooNetBanner        180
# FaceBoom              180
# AdNonSense            180
# RocketSuperAds        180
# Name: channel, dtype: int64

# %% [markdown]
# Видим, что в значениях присутсвуют загщавные буквы приведем данные столбййы к нижнем регистру

# %%
for col in ['region', 'device', 'channel']:
    visits.loc[:, col] = visits[col].str.lower()

# %%
costs['channel']=costs['channel'].str.lower()

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для создания пользовательских профилей

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

   
    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )
    

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles

# %% [markdown]
# ### Функция для расчёта конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для расчёта удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для визуализации удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Профили пользователей. Определение минимальной и максимальной даты привлечения пользователей.

# %% [markdown]
# Создадим пользовательский профиль

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    faceboom     mac  united states
# 1   4919697 2019-07-09 12:46:07    faceboom  iphone  united states
# 2   6085896 2019-10-01 09:58:33     organic  iphone         france
# 3  22593348 2019-08-22 21:35:48  adnonsense      pc        germany
# 4  31989216 2019-10-02 00:07:44     yrabbit  iphone  united states
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определяем первого и последнего привлеченного пользователя в нашем датасете

# %%
min_analysis_date = profiles['dt'].min()
max_analysis_date = profiles['dt'].max()
print('Первое привлечение пользователя:', min_analysis_date)
print('Последнее привлечение пользователя:', max_analysis_date)
# Out:
# Первое привлечение пользователя: 2019-05-01
# Последнее привлечение пользователя: 2019-10-27

# %% [markdown]
# - Получили таблицу, где есть данные о дате первого посещения и рекламном источнике, который мотивировал пользователя посетить интернет-магазин, о девайсе, с которого пользователь заходил в приложение и регион места нахождения пользователя.
# - Определены первая и последняя даты привлечения пользователей: 2019-05-01 и 2019-10-27

# %% [markdown]
# ### Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?

# %%
profiles.groupby('region').agg({'user_id': 'nunique','payer': 'sum', 'payer': 'mean'}).sort_values(by='payer',ascending = False)
# Out:
#                user_id     payer
# region
# united states   100002  0.069019
# germany          14981  0.041119
# uk               17575  0.039829
# france           17450  0.037994

# %% [markdown]
# - Посетители приходят из таких стран как США, Германия, Британия и Франция.
# - Больше всего посетителей у США - 100 002, меньше всего у Франции - 17 450.
# - Больше всего платящих пользователей дает США - 6.9% платящих пользователей.

# %% [markdown]
# ### Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?

# %%
profiles.groupby('device').agg({'user_id': 'nunique','payer': 'sum', 'payer': 'mean'}).sort_values(by='payer',ascending = False)
# Out:
#          user_id     payer
# device
# mac        30042  0.063644
# iphone     54479  0.062079
# android    35032  0.058518
# pc         30455  0.050468

# %% [markdown]
# - Посетители пользуются следкющими устройствами : mac, iphone, android, pc.
# - Больше всего посетителей пользуются iphone - 54 479 посетителей, меньше всего пользуются рс - 30455 пользователей.
# - Больше всего платящих пользователей заходят с устройств  mac и iphone - 6,3 и 6,2 % соответсвенно.

# %% [markdown]
# ### По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
profiles.groupby('channel').agg({'user_id': 'nunique','payer': 'sum', 'payer': 'mean'}).sort_values(by='payer',ascending = False)
# Out:
#                     user_id     payer
# channel
# faceboom              29144  0.122049
# adnonsense             3880  0.113402
# lambdamediaads         2149  0.104700
# tiptop                19561  0.096007
# rocketsuperads         4448  0.079137
# wahoonetbanner         8553  0.052964
# yrabbit                4312  0.038265
# mediatornado           4364  0.035747
# leapbob                8553  0.030633
# opplecreativemedia     8605  0.027077
# organic               56439  0.020553

# %% [markdown]
# - Привлечение пользователей шло по следующим каналам: faceboom,adnonsense,lambdamediaads,tiptop,rocketsuperads,wahoonetbanner,yrabbit,mediatornado,	leapbob,opplecreativemedia,organic.
# - Больше всего привлечение пользоватей было благодаря каналу organic - 56 439 пользователей, меньше всего по каналу ambdamediaads - 2 149.
# - Каналы faceboom,adnonsense,lambdamediaads	приносят больше всего платящих пользователей: 12,2, 11,3 и 10,4 процента.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# - Определены первая и последняя даты привлечения пользователей: 2019-05-01 и 2019-10-27,
# - Посетители приходят из таких стран как США, Германия, Британия и Франция. Больше всего посетителей у США - 100 002, меньше всего у Франции - 17 450. Больше всего платящих пользователей дает США - 6.9% платящих пользователей,
# - Посетители пользуются следкющими устройствами : mac, iphone, android, pc. Больше всего посетителей пользуются iphone - 54 479 посетителей, меньше всего пользуются рс - 30455 пользователей. Больше всего платящих пользователей заходят с устройств mac и iphone - 6,3 и 6,2 % соответсвенно,
# - Больше всего привлечение пользоватей было благодаря каналу organic - 56 439 пользователей, меньше всего по каналу ambdamediaads - 2 149.Каналы faceboom,adnonsense,lambdamediaads приносят больше всего платящих пользователей: 12,2, 11,3 и 10,4 процента.

# %% [markdown]
# ##  Маркетинг

# %% [markdown]
# ### Общая сумма расходов  на маркетинг

# %%
all_coasts=costs['costs'].sum()
print('Oбщая сумма расходов на маркетинг', all_coasts, 'у.е.')
# Out:
# Oбщая сумма расходов на маркетинг 105497.30000000002 у.е.

# %% [markdown]
# ### Как траты распределены по источникам

# %%
costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs',ascending = False)
# Out:
#                        costs
# channel
# tiptop              54751.30
# faceboom            32445.60
# wahoonetbanner       5151.00
# adnonsense           3911.25
# opplecreativemedia   2151.25
# rocketsuperads       1833.00
# leapbob              1797.60
# lambdamediaads       1557.60
# mediatornado          954.48
# yrabbit               944.22

# %% [markdown]
# Больше всего расходов у таким рекламных источников как tiptop - 54 751,3 у.е. и faceboom - 32 445,6 у.е. У остальных рекламных истчочников расходы на порядок меньше.

# %% [markdown]
# ### Визуализация изменений метрик во времени

# %%
costs.pivot_table(
    index='dt', columns='channel', values='costs', aggfunc='sum'
).plot(grid=True, figsize=(20, 10))
plt.ylabel('costs, у.е')
plt.xlabel('Дата проведения рекламной компании')
plt.title('Изменение метрик по времени')
plt.show()

# %% [markdown]
# Из графика видно, что у нас есть два явных лидера - каналы TipTop и FaceBoom.
# Наибольшие расходы и бюджета на маркетинг пришлись на октябрь 2019 года, меньще всего фиксровалось в мае 2019 года. Затраты на TipTop в течение исследуемого периода не так стабильны, относительно другтх каналов привлечения.

# %% [markdown]
# ### Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Рассчитаем средний CAC на одного покупателя для всего проекта.

# %% [markdown]
# Чтобы оценить среднюю стоимость привлечения пользователя по проекту уберем органический канад привлечения пользователей.

# %%
profiles = profiles.query('channel != "organic"')

# %%
cac_mean = all_coasts/profiles['user_id'].nunique()
print('Средняя стоимость привлечения покупателя по проекту:', cac_mean)
# Out:
# Средняя стоимость привлечения покупателя по проекту: 1.127481323942759

# %% [markdown]
# Сколько в среднем стоило привлечение одного покупателя из каждого источника

# %%
profiles.groupby('channel').agg({'acquisition_cost': 'mean'}).sort_values(by='acquisition_cost',ascending = False)
# Out:
#                     acquisition_cost
# channel
# tiptop                      2.799003
# faceboom                    1.113286
# adnonsense                  1.008054
# lambdamediaads              0.724802
# wahoonetbanner              0.602245
# rocketsuperads              0.412095
# opplecreativemedia          0.250000
# yrabbit                     0.218975
# mediatornado                0.218717
# leapbob                     0.210172

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# - Oбщая сумма расходов на маркетинг 105497.30000000002 у.е.
# - Больше всего расходов у таким рекламных источников как tiptop - 54 751,3 у.е. и faceboom - 32 445,6 у.е. У остальных рекламных истчоников расходы на порядок меньше
# - По средней стоимости привлечения на одного пользователя канал tiptop в лидерах, у него стоимость привлеечения больше чем в два раза, чем у faceboom.
# - Больше половины бюджета уходит только на два канала привлечени: tiptop и faceboom.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Установим момент и горизонт анализа данных.
# Предположим, что на календаре 1 ноябряя 2019 года, и зададим недельный горизонт анализа.

# %%
observation_date = datetime(2019, 11, 1).date()  # момент анализа
horizon_days = 14  # горизонт анализа

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
   profiles, orders, observation_date, horizon_days
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=10)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - Реклама не окупается, ROI через две недели после привлечения равен - 0,8.
# - Кривая динамики ROI резко упала с мая по июнь, далее идет постепенный спад и снова скачок в июне, а далее толкьо спад и динамика окупаемости ниже уровня затрат.
# - CAC не стабилен. Постоянно увеличивался рекламный бюджет. Можно заметить, что с мая по июнь идет резкий скачок стоимости рекламных компаний, а далее более плавный рост. Видимо маркетологи закупили трафик в очень дорогих источниках, следовательно поэтому способность окупить затраты на рекламу становится сложнее (это заметно про графикам ROI).
# - На графике LTV видно, что данный показатель достаточно стабилен. Значит, дело не в ухудшении качества пользователей.
# - LTV в динамике имеет цикличность и напоминает синусоиду, с конца каждого месяца имеет подъем до середины следующего месяца, а потом спад.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Чтобы разобраться в причинах, посмотрим графики по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.

# %%
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# По графикам можно сделать следующие выводы:
# - Реклама окупается только для пользователей pc.
# - Динамика ROI на 14 день после привлечения резко упала с мая по июнь для пользователей mac, iphone, android и далее до октября находились ниже окупаемости или на границе с затратами выходя в "ноль". Динамика для pc была самой лучшей по окупаемости до июля, далее пошел спад и снова скачок в агусте, но рост не удалсь сохранить и с сентября по октябрь пользоватлеи pc не окупались.
# - Стоимость привлечения (САС) для mac и iphone выше, чем для пользователей android и pc.
# - LTV всё так же стабилен для всех девайсов.
# - LTV в динамике имеет цикличность и напоминает синусоиду, с конца каждого месяца имеет подъем до середины следующего месяца, а потом спад. Пользователи на pc обладают меньшей жизненной ценостью потносительно других девайсов.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# - Реклама окупается только для пользователей из Франции, Германии, Британии, не окупается для пользователей США.
# - Динамика ROI на 14 день после привлечения только для США отрицательная и ниже окупаемости в период с июня по октябрь.
# - Стоимость привлечения (САС) для пользоватлей из США на порядок выше, чем для пользователей из других стран.
# - LTV всё так же стабилен, но можно сказать, что «пожизненная ценность» клиента выше для пользоватлей из США.
# - в динамике LTV все страны выделяются перепадами в ту или иную сторону, более сглаженная кривая, без резких перепадов у США, самые выраженные перепады у Британии.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# По графикам можно сделать следующие выводы:
#
# - Реклама окупается практически для большиства рекламных компаний кроме tiptop, adnonsense и faceboom.
# - Самая высокая стоимость привлечения (САС) у рекламной компании tiptop, для других рекламных компаний стоимость привлечения стабильна и одинакова.
# - В динамике ROI все каналы уходят в плюс уже со 2-го дня и окупаются или выходят на "ноль", кроме tiptop и faceboom,  adnonesense. Самая лучшая окупаемость у канала yrabbit, особенно выделяются в динамике июль-август.
# - LTV всё так же стабилен. Самый хороший рост показывает канал lambdamediaads и tiptop.

# %% [markdown]
# ### Промежуточные итоги

# %% [markdown]
# - Реклама в целом по проекту за исследуемый период времени не окупается. Кривая динамики ROI резко упала с мая по июнь, далее идет постепенный спад и с июля ROI уже не поднимается выше отметки окупаемости.
# - CAC не стабилен. Постоянно увеличивался рекламный бюджет. Можно заметить, что с июне идет резкий скачок стоимости рекламных компаний. Видимо маркетологи закупили трафик в очень дорогих источниках, следовательно поэтому способность окупить затраты на рекламу становится сложнее (это заметно про графикам ROI).
# - Каналы привлечения faceboom, tiptop убыточны. Каналы yrabbit- самый доходный и перспективный.
# - Если говорить о странах, то расходов больше всего у США и реклама на пользовталей из США убыточна для компании, остальные страны прибыльны. По США лушие показатели по LTV, но из-за высокого роста на стоимость привлечения доходы не покрывают расходы.
# - Также можно отследить связь: динамика увеличения расходов на канал привлечения tiptop схож с динмикой роста LTV у США. Можно предположить, что каналом привлечения tiptop пользуются только американские пользователи, далее в проекте проерим данную гипотезу.

# %% [markdown]
# ###  Графики конверсии и удержания с разбивкой по устройствам, странам, рекламным каналам

# %% [markdown]
# Оценив общую ситуацию — посмотрев на окупаемость рекламы, получили несколько зацепок и посмотрим теперь в чем дело в низкой конверсии или низком удержании

# %%
# смотрим конверсию с разбивкой по устройствам
dimensions = ['device']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи iPhone и mac конвертируются очень хорошо, но не постоянно. Хуже всего ковенртируются пользователи pc. Динамика конверсии имеет спад и подъем - похоже на синусоиду. Конверсия для ps имеет сильный спад в июле.

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['device']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Пользователи iPhone и mac хуже всего удерживаются в отличие от других девайсов, но разница удежаниия среди девайсов сосвем минимальна. Удержание неплатящих пользователей и платящих пользователей практически одинокова для пользователей всех девайсов, значит скорее всего проблема не в использовании какого-либо определнного девайса. Продолждаем дальше искать реальные причины убытков.

# %%
# смотрим конверсию с разбивкой по cтранам
dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи из США лучше всех конвертируются и постоянно. Остальные страны по конверсии и динамики конверсии находятся на одном уровне. В динамике в мае у всех стран, кроме США отмечается высокая конверсия. Далее в июне у этих стран идет резкий спад, а в США наооброт рост, что связано скорее всего с применением каналов привлечения tiptop и faceboom.

# %%
# смотрим удержание с разбивкой по устройствам
dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# При хорошей конверсии пользователи из США плохо удерживаются. Пользователи из других стран стабильно удерживаются на одном уровне.
# Надо подробнее рассмотреть как ведут себя пользователи из США и почему они быстро отваливаются.

# %%
# смотрим конверсию с разбивкой по рекламным каналам
dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, стабильно и лучше всего конвертируются пользователи пришедшие из следующих каналов привлечения: faceboom, adnonsense, lambdamediaads, tiptop.

# %%
# смотрим удержание с разбивкой по рекламным каналам
dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# При хорошей конверсии каналы привлечения  faceboom, adnonsense плохо удерживаются. Оставшиеся каналы привлечения удерживаются на одном уровне.

# %% [markdown]
# *Проанализировав окупаемость и удеражние необходимо отдельно рассмотреть как работают убыточные каналы привлечения (tiptop,faceboom) для США, возможно там мы найдем какую-нибудь зацепку.*

# %%
profiles.query('channel in ("tiptop", "faceboom")').groupby('region')['user_id'].count()
# Out:
# region
# united states    48705
# Name: user_id, dtype: int64

# %% [markdown]
# Действительно, каналы привлечения пользователей tiptop, faceboom работают только для пользователей из США.

# %%
profiles.query('region == "united states" & channel != "organic"').groupby('channel').agg({'user_id': 'count'}).plot(y = 'user_id', 
                                                      autopct='%.2f', 
                                                      kind = 'pie', 
                                                      figsize = (15, 7), 
                                                      legend = False);
plt.xlabel('Кол-во привлеченных пользователей из США по каналам прихода, %')
plt.show();

# %% [markdown]
# Исходя из круговой диаграммы видно, что для США основные каналы привлечения это faceboom - 47,14% и tiptop - 31,64%. Самый прибильный канал привлечения - yrabbit меньше всего задействован - 6,97%.

# %% [markdown]
# ### Ответы на вопросы

# %% [markdown]
# - Окупается ли реклама в целом?
#
# Рекламный бюджет не окупается для проекта за 14 дней.
# - Какие устройства, страны и каналы могут снижать окупаемость рекламы?
#
# Из стран снижает окупаемость - США; каналы привлечения faceboom, tiptop, adnonsense снижают окупаемость рекламы; польхователи, у которых mac и iphone не окупатся, так как ими пользутся живущие в США.
# - Чем могут быть вызваны проблемы окупаемости?
#
# Проблемы с неокупаемостью вызвана огромными расходами на faceboom и tiptop, которые составляют больше половины от рекламного бюджета.
#
# **Промежуточные рекомендации**
#
# Необходимо разобраться с причинами повышения затрат на пользователя каждый месяц у канала tiptop, так как у этого канала ярко выраженное повышениц цен каждый месяц исходя из кривой графика. А также исследовать канал faceboom, так как канал имеет хорошую конверсию, но дальше видимо покупатели второй раз не приходят, удержания практически нет.

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Причины неэффективности привлечения пользователей:**

# %% [markdown]
# - Согласно кривым динамики ROI реклама окупается только для пользователей из Франции, Германии, Британии. Не окупается для пользователей США, так ROI для США находится ниже отметки окупаемости.
# - Стоимость привлечения (САС) для пользоватлей из США на порядок выше, чем для пользователей из других стран.
# - Имея хорошую конверсию пользователи из США плохо удерживаются.
# - Самая высокая стоимость привлечения (САС) у рекламной компании tiptop, для других рекламных компаний стоимость привлечения стабильна и одинакова.
# - Согласно значениям ROI реклама окупается практически для большиства рекламных компаний кроме tiptop, adnonsense и faceboom.
# - Удержание пользователей канала привлечения faceboom слабое, хотя имеет высокую конверсию.
# - Проблемы с неокупаемостью вызвана огромными расходами на faceboom и tiptop, которые составляют больше половины от рекламного бюджета.
# - Для США основными каналами привлечения яввляются faceboom - 47,14% и tiptop - 31,64%, которые не приносят прибыль. Самый прибильный канал привлечения - yrabbit меньше всего задействован - 6,97%.

# %% [markdown]
# **Рекомендации для отдела маркетинга для повышения эффективности**

# %% [markdown]
# - Перераспределить расходы по каналам привлечения и по странам более раномерно.
# - Возможно договориться с каналами приривлечения faceboom и tiptop и снизить стоимость привлечения клиента, либо отказаться вовсе от них и вложить деньги в более перспективные каналы например, yrabbit, lambdamediads.
# - Провести расследование почему пользователи канала привлечения faceboom имеют хорошую конверсию, но очень слаюо удерживаются.
# - Обратить внимание на канал adnonsense по нему нет окупаемости в течении двух недель. Можно договриться о снижении цены с данным каналом привлечения.
# - Развивать каналы yrabbit, lambdamediads, mediatornado - они стабильны и приносят прибыль.
# - Помимо двух каналов faceboom и tiptop еще не окупается канал adnonesens. По нему можно попробовать договриться снизить цену или вовсе отказаться от него.
