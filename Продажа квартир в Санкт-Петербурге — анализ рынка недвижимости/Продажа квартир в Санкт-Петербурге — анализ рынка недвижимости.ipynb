# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1">Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1">Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2">Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1">Обработка пропусков</a></span></li><li><span><a href="#Изменение-наименования-столбцов" data-toc-modified-id="Изменение-наименования-столбцов-2.2">Изменение наименования столбцов</a></span></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-2.3">Замена типов данных</a></span></li><li><span><a href="#Поиск-и-удаление-дубликатов" data-toc-modified-id="Поиск-и-удаление-дубликатов-2.4">Поиск и удаление дубликатов</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-2.5">Вывод по разделу</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3">Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1">Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2">День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры" data-toc-modified-id="Этаж-квартиры-3.3">Этаж квартиры</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади-и-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади-и-отношение-площади-кухни-к-общей-3.4">Соотношение жилой и общей площади и отношение площади кухни к общей</a></span></li><li><span><a href="#Вывод-по-разделу" data-toc-modified-id="Вывод-по-разделу-3.5">Вывод по разделу</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4">Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучение-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-Построение-гистограммы-для-каждого-параметра.-4.1">Изучение следующих параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1">Площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.1.2">Цена</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3">Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4">Высота потолков</a></span></li><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.1.5">Вывод по пункту</a></span></li></ul></li><li><span><a href="#Изучение-время-продажи-квартиры.-Построение-гистограммы.-Расчет-среднего-и-медианы.-Описать,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучение-время-продажи-квартиры.-Построение-гистограммы.-Расчет-среднего-и-медианы.-Описать,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2">Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.2.1">Вывод по пункту</a></span><ul class="toc-item"><li><span><a href="#Убираем-редкие-и-выбивающиеся-значения.-Описание,-какие-особенности-обнаружили." data-toc-modified-id="Убираем-редкие-и-выбивающиеся-значения.-Описание,-какие-особенности-обнаружили.-4.2.1.1">Убираем редкие и выбивающиеся значения. Описание, какие особенности обнаружили.</a></span></li></ul></li><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.2.2">Вывод по пункту</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучить-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучить,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучить-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.3">Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.3.1">Вывод по пункту</a></span></li></ul></li><li><span><a href="#Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выбрать-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитать-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделить-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.4">Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.4.1">Вывод по пункту</a></span></li></ul></li><li><span><a href="#Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитать-среднюю-цену-для-каждого-километра.-Построить-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определить-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучить-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделить-квартиры-в-Санкт-Петербурге-(locality_name).-Задача-—-выяснить,-какая-область-входит-в-центр.-Создать-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитать-среднюю-цену-для-каждого-километра.-Построить-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определить-границу,-где-график-сильно-меняется,-—-это-и-будет-центральная-зона.-4.5">Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.5.1">Вывод по пункту</a></span></li></ul></li><li><span><a href="#Выделить-сегмент-квартир-в-центре.-Проанализировать-эту-территорию-и-изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделить-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделать-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу" data-toc-modified-id="Выделить-сегмент-квартир-в-центре.-Проанализировать-эту-территорию-и-изучить-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделить-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделать-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу-4.6">Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-пункту" data-toc-modified-id="Вывод-по-пункту-4.6.1">Вывод по пункту</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5">Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Цель работы**: Провести исследовательский анализ данных объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет для определения рыночной стоимости недвижимости.

# %% [markdown]
# **Задачи работы**:
#
# 1.Изучить данные.
#
# 2.Выполнить предообработку данных.
#
# 3.Посчитать и добавить в таблицу: цену квадратного метра; день недели, месяц и год публикации объявления; этаж квартиры; соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# 4.Провести исследовательский анализ данных.

# %% [markdown]
# **План работы**
#
# ***Шаг 1***. Открыть файл с данными и изучить общую информацию
# Путь к файлу: /datasets/real_estate_data.csv.Скачать датасет
#
# ***Шаг 2***. Предобработка данных
# Определить и изучить пропущенные значения:
#
# Для некоторых пропущенных значений можно предположить логичную замену. Например, если человек не указал число балконов — скорее всего, их нет. Такие пропуски правильно заменить на 0. Для других типов данных нет подходящего значения на замену. В этом случае правильно оставить эти значения пустыми. Отсутствие значения — тоже важный сигнал, который не нужно прятать.
#
# Заполнить пропуски, где это уместно. Описать, почему вы решили заполнить пропуски именно в этих столбцах и как выбрали значения.
#
# Указать причины, которые могли привести к пропускам в данных.
#
# Приведите данные к нужным типам:
#
# Поясните, в каких столбцах нужно изменить тип данных и почему.
#
# ***Шаг 3***. Посчитать и добавить в таблицу цену квадратного метра; день недели, месяц и год публикации объявления; этаж квартиры; варианты — первый, последний, другой;соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# ***Шаг 4***. Провести исследовательский анализ данных и выполнить инструкции
#
# Изучить следующие параметры: площадь, цена, число комнат, высота потолков. Построить гистограммы для каждого параметра.
#
# Изучить время продажи квартиры. Построить гистограмму. Посчитать среднее и медиану. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
#
# Убрать редкие и выбивающиеся значения. Описать, какие особенности обнаружили.
#
# Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучить зависимость от даты размещения: дня недели, месяца и года.
#
# Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.
#
# Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. СоздаТЬ столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитаТЬ среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.
# Выделить сегмент квартир в центре. Проанализировать эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу?
#
# ***Шаг 5***. Написать общий вывод

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Импорт библиотек, с которыми предстоит работать в ходе проекта

# %%
import pandas as pd 
from pymystem3 import Mystem
m = Mystem()
import matplotlib.pyplot as plt
import math
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Чтение файла с данными и сохранение в переменную df

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %% [markdown]
# Получение первых 10 строк таблицы df для ознакомления с данными

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# Получение общей информации о данных в таблице df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Проверка стиля названий столбцов таблицы

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Просмотр основных статистических показателей данны в таблице

# %%
df.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# Подсчет пропущенных значений в столбцах

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Подсчет количества явных дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# В каждой строке таблицы — данные из объявлений сервиса Яндекс.Недвижимость.
#
# Пользуясь методами head(), info(), describe() было выявлено: в таблице 22 столбца, 23699 строк, типы данных: bool(2), float64(14), int64(3), object(3).
#
# Наименование всех столбцов корректно, кроме столбцов 'cityCenters_nearest', 'parks_around3000', 'ponds_around3000' - не используется стиль snake_case.
#
# В данных встречаются пропуски. В колонке "ceiling_height" пропущено 9195 строк из 23699, в колонке "floors_total" пропущено 86 строк из 23699, в колонке "living_area" пропущено 1903 строк из 23699, в коолонке "is_apartment" пропущено 20924 строк из 23699, в колонке "kitchen_area" 2278 строк пропущено из 23699, в колонке "balcony" пропущено 11519 строк из 23699, в колонке "locality_name" проущено 49 строк из 23699, в колонке "airports_nearest" пропущено 5542 строк из 23699, в колонке "cityCenters_nearest" пропущено 5519 строк из 23699, в колонке "parks_around3000" пропущено 5518 строк из 23699, в колонке "parks_nearest" пропущено 15620 строк из 23699, в колонке "ponds_around3000" пропущено 5518 строк из 23699, в колонке "ponds_nearest" пропущено 14589 строк из 23699, в колонке "days_exposition" пропущено 3181 строк из 23699.
#
# В датафрейме отсутсвуют явные дубликаты.
#
# Анализируя типы данных в ходе работы необходимо будет заменить типы данных на int, bool и datatime24.
#
# Первичный анализ статистических данных датафрейма.
# В колонке "ceiling_height" - максимальное значение 100 м, такого скорее всего не может быть.
# В большинстве столбцов максимальное значение на порядок выше, чем межквартальных размах, возможно есть выбросы, необходим анализ и построение боксплотов.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Перечень действия для выполнения предобратки данных:
#
# - Обработка пропусков в столбцах, где они есть.
# - Изменение наименования столбцов, где это необходимо
# - Заменить типы данных столбцов на более подходящие
# - Поиск и удаление/замена дубликатов

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# С помощью метода isna().sum() подсчет пропущенных значений в столбцах

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Так как пропусков в таблице много,посмотрим долю пропусков в каждом столбце от общего количества строк. Возможно что-то можно просто удалить

# %%
df.isnull().sum() / df.count()
# Out:
# total_images            0.000000
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.633963
# floors_total            0.003642
# living_area             0.087310
# floor                   0.000000
# is_apartment            7.540180
# studio                  0.000000
# open_plan               0.000000
# kitchen_area            0.106344
# balcony                 0.945731
# locality_name           0.002072
# airports_nearest        0.305227
# cityCenters_nearest     0.303575
# parks_around3000        0.303504
# parks_nearest           1.933408
# ponds_around3000        0.303504
# ponds_nearest           1.601427
# days_exposition         0.155035
# dtype: float64

# %% [markdown]
# Видим, что наименьший процент пропусков в столбце "floors_total" - 0,4 %, в столбце "locality_name" - 0,2%. Их можно просто удалить

# %%
df.dropna(subset=['floors_total'], inplace=True)
print('Пропуски после:', df['floors_total'].isna().sum())
# Out:
# Пропуски после: 0

# %%
df.dropna(subset=['locality_name'], inplace=True)
print('Пропуски после:', df['locality_name'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# Заменим пропуски медианным значением в столбце 'ceiling_height'.

# %% [markdown]
# Посмотрим медиану

# %%
df['ceiling_height'].describe().T
# Out:
# count    14481.000000
# mean         2.771283
# std          1.261983
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Медианное значение - 2,65м, отлично! Тем более данное значение самое популярное и часто встречающиеся по стране

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(2.65)
print('Пропуски после:', df['ceiling_height'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# Пропуски в столбце "ceiling_height" скорее всего связаны с тем, что пользователи не всегда знают высоту потолков и поэтому зачастую не указывают в объявлении высоту потолков.

# %% [markdown]
# Заменим пропуски в столбце "balcony" на 0, так как если человек их не указал, то значит скорее всего балкона нет в квартире.

# %%
df['balcony'] = df['balcony'].fillna(0)
print('Пропуски после:', df['balcony'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# В столбце "is_apartment", проверим сначала уникальные значения.

# %%
df['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# В данном столбце пропуски скорее всего, это False, так как аппартаменты - большая редкость, а попуск обозначает, что кварира в объявлении не является аппартаментами. Заполним пропуски на 0. А далее в ходе работы в пункте Замена типов данных поменяем тип на bool и значение 0 - станет False.

# %%
df['is_apartment'] = df['is_apartment'].fillna(0)
print('Пропуски после:', df['is_apartment'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# У нас есть пропуски в столбце "living_area" и "kitchen_area", данные в этих столбцах описывают значения площади недвижимости, значит эти столбцы взаимосвязаны. Есть еще столбец с значениями общей площади "total_area"его тоже будем иметь в виду. Воспользуемся методом заполнения пропусков медианой с группировкой по нескольким перемнным.

# %%
medians = (df.groupby(['kitchen_area', 'total_area']).agg({'living_area': 'median'}).rename(columns = {'living_area': 'median_living_area'}))
df = df.merge(medians, on = ['kitchen_area', 'total_area'])

# %%
medians_1 = (df.groupby(['living_area', 'total_area']).agg({'kitchen_area': 'median'}).rename(columns = {'kitchen_area': 'median_kitchen_area'}))
df = df.merge(medians_1, on = ['living_area', 'total_area'])

# %%
df.loc[df['living_area'].isna(), 'living_area'] = df.loc[df['living_area'].isna(), 'median_living_area']
print('Пропуски после:', df['living_area'].isna().sum())
# Out:
# Пропуски после: 0

# %%
df.loc[df['kitchen_area'].isna(), 'kitchen_area'] = df.loc[df['kitchen_area'].isna(), 'median_kitchen_area']
print('Пропуски после:', df['kitchen_area'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# Пропуски в столбцах, связанные с значениями жилой площади и с площадью кухни, появились скорее всего от незнания данных значений. Обычно все знают общую площадь и опирируют этим значением, а вот разделение площади на жилую часть или сколько квадратных метров из ощего метража занимает кухня - уже вопрос сложнее.

# %%
df['days_exposition'].isna().sum()
# Out:
# 2885

# %% [markdown]
# В столбце "days_exposition" много пропусков, в данном случае пропуски скорее всего означают, что объявление до сих пор актуально и не снято с публикации. Заменим пропуски в данном случае на 0, это будкт своеобразным маркером для нас. Мы будем знать, что при значени ии 0 - обьявление не снято с публикации.

# %%
df['days_exposition'] = df['days_exposition'].fillna(0)
print('Пропуски после:', df['is_apartment'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# В столбце "cityCenters_nearest" посмотрим пропуски для Санкт-Петербурга , так как это нужно в дальнейшем для исследования.

# %%
df[(df['locality_name'] == 'Санкт-Петербург') & (df['cityCenters_nearest'].isna())]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 1924             19    7099000.0       52.00  2018-11-04T00:00:00      2
# 2852             14    5650000.0       51.00  2019-02-26T00:00:00      2
# 4541             13    3100000.0       32.00  2019-03-15T00:00:00      1
# 4582              8    4400000.0       50.00  2017-05-12T00:00:00      2
# 5706              7    3400000.0       31.00  2019-01-16T00:00:00      1
# 5859             20    4200000.0       38.30  2019-04-16T00:00:00      1
# 5949             11    9899000.0      101.00  2018-12-12T00:00:00      3
# 6584              5    7299000.0       75.00  2019-04-18T00:00:00      3
# 6623             19    7100000.0       59.60  2019-02-13T00:00:00      2
# 8049             12   18500000.0       66.00  2017-06-08T00:00:00      1
# 8117             14    6300000.0       58.00  2017-02-12T00:00:00      2
# 8404              7    6500000.0       67.00  2019-04-24T00:00:00      3
# ...

# %% [markdown]
# Всего лишь в 43 строках пропущено значение расстояния от центра для города Санкт-Петербурга. Посмотрим долю пропусков  для города Санкт-Петербурга относительно всех строк для города Санкт-Петербурга в данном датафрейме.

# %%
round(len(df[(df['locality_name'] == 'Санкт-Петербург') & (df['cityCenters_nearest'].isna())]) / len(df.reset_index(drop=True).query('locality_name == "Санкт-Петербург"')), 3)
# Out:
# 0.003

# %% [markdown]
# Видим, что пропуски для всех строк для города Санкт-Петербург составяет 0,3 %, что очень мало. Оставим пропуски как есть, не заменяя их. Так как данные об удаленности от центра скорее всего выгружались автоматически на основе данных яндекс карт и заменять их медианами не целесообразно.

# %%
df.corr().T
# Out:
#                      total_images  last_price  total_area     rooms  \
# total_images             1.000000    0.114846    0.117334  0.092415
# last_price               0.114846    1.000000    0.691147  0.390793
# total_area               0.117334    0.691147    1.000000  0.772533
# rooms                    0.092415    0.390793    0.772533  1.000000
# ceiling_height           0.003507    0.075627    0.085522  0.051215
# floors_total             0.019858    0.000688   -0.061795 -0.213696
# living_area              0.101296    0.603048    0.939732  0.850709
# floor                    0.038992    0.031402   -0.016237 -0.143349
# studio                        NaN         NaN         NaN       NaN
# open_plan                     NaN         NaN         NaN       NaN
# kitchen_area             0.111899    0.517958    0.609508  0.269998
# balcony                  0.036353    0.004808    0.010007 -0.014576
# airports_nearest        -0.001805   -0.029862   -0.035167 -0.065705
# ...

# %% [markdown]
# Данные в столбцах "airports_nearest", "parks_nearest", "ponds_nearest" скорее всего выгружались автоматически на основе данных яндекс-карт, а пропуски являются ошибкой при выгрузке данных, о которой необходимо сообщить отделу, который этим занимается. Менять на медианы здесь не целесообразно, так как даже мы не можем опереться на другие данные из таблицы(значения из данных столбцов не имеет ни с какими данными сильную линейную связь), тем более данные не участуют далее в исследованиях, поэтому оставим их без измнения.

# %% [markdown]
# Остались столбцы с пропусками "parks_around3000" и "ponds_around3000", посмотрим их уникальные значения.

# %%
df['parks_around3000'].unique()
# Out:
# array([ 1.,  0., nan,  2.,  3.])

# %%
df['ponds_around3000'].unique()
# Out:
# array([ 2.,  0., nan,  1.,  3.])

# %% [markdown]
# Скорее всего в двух столбцах пропуски обозначеют, что в радиусе 3 км отсутствуют парки и пруды и полльзователь вместо 0 оставил пропуск. Поэтому заменим их на нулевое значение.

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0)
print('Пропуски после:', df['parks_around3000'].isna().sum())
# Out:
# Пропуски после: 0

# %%
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)
print('Пропуски после:', df['ponds_around3000'].isna().sum())
# Out:
# Пропуски после: 0

# %% [markdown]
# ### Изменение наименования столбцов

# %%
df.rename(columns = {'cityCenters_nearest':'city_centers_nearest','parks_around3000':'parks_around_3000', 'ponds_around3000':'ponds_around_3000'}, inplace=True)

# %% [markdown]
# Проверка заменились ли названия столбцов

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around_3000', 'parks_nearest', 'ponds_around_3000',
#        'ponds_nearest', 'days_exposition', 'median_living_area',
#        'median_kitchen_area'],
#       dtype='object')

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# В колонке "first_day_exposition" заменить  на datetime64, в колонке "floors_total" заменить на int, в колонке "balcony" заменить на int, в колонке "days_exposition" заменить на int, в колонке 'last_price' заменить на int.
#
# Колонки "airports_nearest", "cityCenters_nearest", "parks_around3000", "parks_nearest", "ponds_around3000", "ponds_nearest" не будем преобразовывать, так как в данных столбцах мы оставили пропуски, которые нельзя будет преобразовать к целочисленному типу, тем более все колонки кроме "cityCenters_nearest" не будут участовать в исследовании.
# Колонки, связанные с площадью недвижимости также не будем трогать, так как это очень точные значения, которые при преобразовании в int или округление с помощью round могут привети к неточным значениям.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')
print(df['first_day_exposition'].head())
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2018-10-22
# 3   2017-08-28
# 4   2018-11-12
# Name: first_day_exposition, dtype: datetime64[ns]

# %%
df['floors_total'] = df['floors_total'].astype('int') 
print(df['floors_total'].head())
# Out:
# 0    16
# 1    11
# 2    10
# 3    10
# 4    10
# Name: floors_total, dtype: int64

# %%
df['balcony'] = df['balcony'].astype(('int'))
print(df['balcony'].head())
# Out:
# 0    0
# 1    2
# 2    1
# 3    2
# 4    0
# Name: balcony, dtype: int64

# %%
df['last_price'] = df['last_price'].astype('int')
print(df['last_price'].head())
# Out:
# 0    13000000
# 1     3350000
# 2     2995000
# 3     2800000
# 4     4250000
# Name: last_price, dtype: int64

# %%
df['is_apartment'] = df['is_apartment'].astype('bool')
print(df['is_apartment'].head())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: is_apartment, dtype: bool

# %% [markdown]
# Проверим, что у нас получилось

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20905 entries, 0 to 20904
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20905 non-null  int64
#  1   last_price            20905 non-null  int64
#  2   total_area            20905 non-null  float64
#  3   first_day_exposition  20905 non-null  datetime64[ns]
#  4   rooms                 20905 non-null  int64
#  5   ceiling_height        20905 non-null  float64
#  6   floors_total          20905 non-null  int64
#  7   living_area           20905 non-null  float64
#  8   floor                 20905 non-null  int64
#  9   is_apartment          20905 non-null  bool
#  10  studio                20905 non-null  bool
#  11  open_plan             20905 non-null  bool
#  12  kitchen_area          20905 non-null  float64
#  13  balcony               20905 non-null  int64
#  14  locality_name         20905 non-null  object
# ...

# %% [markdown]
# ### Поиск и удаление дубликатов

# %% [markdown]
# Посмотрим количество явных дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Отлично, их нет. Теперь посмотрим есть ли неявные дубликаты

# %%
df['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# Анализируя уникальные значения мы видим, что используются заглавнеы буквы, приведем все к строчным буквам

# %%
df['locality_name'] = df['locality_name'].str.lower()

# %% [markdown]
# Также видим, что в слове поселок используется то буква "Е", то буква "Ё", приведем все к единому виду

# %%
df['locality_name'] = df['locality_name'].str.replace('поселок','посёлок')

# %% [markdown]
# Из задания к проекту понятно, что нам понадобится только топ 10 населенных пунктов по кол-ву объявлений. Проверим есть ли у них дубликаты

# %%
table_1 = df.pivot_table(index=['locality_name'], values= 'last_price', aggfunc =['count'])
table_1.columns = ['count']
table_1.sort_values(by='count', ascending=False).head(10)
# Out:
#                    count
# locality_name
# санкт-петербург    14037
# посёлок мурино       430
# посёлок шушары       392
# всеволожск           357
# пушкин               337
# колпино              322
# гатчина              290
# посёлок парголово    288
# деревня кудрово      226
# выборг               190

# %%
df['locality_name'].value_counts().head(50)
# Out:
# санкт-петербург                            14037
# посёлок мурино                               430
# посёлок шушары                               392
# всеволожск                                   357
# пушкин                                       337
# колпино                                      322
# гатчина                                      290
# посёлок парголово                            288
# деревня кудрово                              226
# петергоф                                     190
# выборг                                       190
# сестрорецк                                   166
# красное село                                 164
# кудрово                                      150
# сертолово                                    132
# деревня новое девяткино                      132
# ломоносов                                    124
# сланцы                                        96
# посёлок бугры                                 95
# ...

# %% [markdown]
# Видим, что не встречается неявных дубликатов для выбранных 10 населенных пунктов, следовательно, на этом закончим нашу предообработку данного столбца.

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# В ходе предообрабоки пропуски в стобцах 'floors_total' и 'locality_name' были удалены, так как они составляли меньше 1 процента всех данных датафрейма. В столбце 'ceiling_height' пропуски заменили медианным значением. В столбце 'balcony' заменили пропуски  на 0. В столбце "is_apartment" заполнили пропуски 0. Заменили пропуски в столбцах 'living_area','kitchen_area' воспользовавшись методом заполнения пропусков медианой с группировкой по нескольким переменным. В столбце 'city_centers_nearest' заменили пропуски в данном случае на 0, это будет своеобразным маркером для нас в ходе дальнейшей работы. Заменили пропуски на 0 в столбцах 'parks_around_3000', 'ponds_around_3000'. Пропуски в столбцах "airports_nearest", "parks_nearest", "ponds_nearest" не заменяли.
#
#
# Изменили наименование столбцов cityCenters_nearest'на'city_centers_nearest','parks_around3000'на'parks_around_3000', 'ponds_around3000' на 'ponds_around_3000'.
#
#
# Столбец "first_day_exposition" приведен к типу datetime64. Столбцы "floors_total", "last_price", "balcony" приведены к типу int64. Столбец 'is_apartment' приведен к типу bool. Колонки "airports_nearest", "cityCenters_nearest", "parks_around3000", "parks_nearest", "ponds_around3000", "ponds_nearest" оставили с типом float.
#
# В столбце 'locality_name' заменили в словах строки "е" на "ё".
#
# В ходе предобработки в датафрейме осталось 20905 строк.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Перечень действий для выполнения расчетов:
# - Определить по заданию какие парметры необходимо добавить в таблицу
# - Поочередно добавить их каждым отдельным столбцом в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# Посчитаем цену квадратного метра и добавим его отдельным столбцом в таблицу.

# %%
df['m_price'] = round(df['last_price'] / df['total_area'], 2)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65            10         18.6      4         False  ...
# 3            2.65            10         18.6      6         False  ...
# 4            2.60            10         18.6      2         False  ...
#
#    airports_nearest  city_centers_nearest  parks_around_3000  parks_nearest  \
# ...

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %% [markdown]
# Добавим отдельными столбцами день недели, месяц и год публикации объявления

# %%
df['weekday'] = df['first_day_exposition'].dt.weekday
df['month'] = df['first_day_exposition'].dt.month
df['year'] = df['first_day_exposition'].dt.year

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65            10         18.6      4         False  ...
# 3            2.65            10         18.6      6         False  ...
# 4            2.60            10         18.6      2         False  ...
#
#    parks_nearest  ponds_around_3000  ponds_nearest  days_exposition  \
# ...

# %% [markdown]
# ### Этаж квартиры

# %% [markdown]
# Добавим отдельным столбцом этаж квартиры; варианты — первый, последний, другой

# %%
def floor_group(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'
df['floor_group'] = df.apply(floor_group, axis=1)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65            10         18.6      4         False  ...
# 3            2.65            10         18.6      6         False  ...
# 4            2.60            10         18.6      2         False  ...
#
#    ponds_around_3000  ponds_nearest  days_exposition  median_living_area  \
# ...

# %% [markdown]
# ### Соотношение жилой и общей площади и отношение площади кухни к общей

# %% [markdown]
# Добавим отдельными столбцами соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
df['ratio_live_total'] = round(df['living_area'] / df['total_area'], 2)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65            10         18.6      4         False  ...
# 3            2.65            10         18.6      6         False  ...
# 4            2.60            10         18.6      2         False  ...
#
#    ponds_nearest  days_exposition  median_living_area  median_kitchen_area  \
# ...

# %%
df['ratio_kitchen_total'] = round(df['kitchen_area'] / df['total_area'], 2)

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65            10         18.6      4         False  ...
# 3            2.65            10         18.6      6         False  ...
# 4            2.60            10         18.6      2         False  ...
#
#    days_exposition  median_living_area  median_kitchen_area    m_price  \
# ...

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# По заданию в исходный датафрейм было добавлено 7 столбцов, в которых были подсчитаны дополнительные параметры: цена квадратного метра; день недели, месяц и год публикации объявления; этаж квартиры; варианты — первый, последний, другой; соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Перечень действия для выполнения исследовательского анализа данных:
# - Поочередно рассмотреть такие параметры как площадь, цена, число комнат, высота потолков (их распредленя и описательные хар-ки). Построить диграмму для каждого из них.
# - Подробно изучить параметр время продажи квартиры, определить какие продажи являются медленными, а какими быстрыми.
# - Проанализировать значения на редкие и выбивающиеся из распределения значения.
# - Определить зависит ли цена от площади, числа комнат, удалённости от центра с помощью корреляуии и столбчатого графика.
# - Определить зависит ли цена от этажа с помощью столбчатого гистограммы.
# - Определить зависит ли цена от даты размещения с использованием группировки или сводных таблиц по среднему значению цены.
# - Отфильтровать таблицу  и найти 10 населённых пунктов с наибольшим числом объявлений.
# - Посчитайть среднюю цену квадратного метра в этих населённых пунктах. Найти из них города с самой высокой и с самой низкой стоимостью.
# - Выделить квартиры в Санкт-Петербурге в отдельную таблицу. Создать столбец с расстоянием до центра в километрах. После этого посчитаем среднюю цену для каждого километра. Построить график зависимости цены от удаленности от центра. По данному графику определить диаметр центральной зоны.
# - Выделить сегмент квартир в центре в отдельную таблицу. Изучить и сравнить следующие параметры: площадь, цена, число комнат, высота потолков для центральной части и для всего горрда. Проанализировать как влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления) в центре и во всем городе. сравнить получивщиеся значения.

# %% [markdown]
# ### Изучение следующих параметров: площадь, цена, число комнат, высота потолков. Построение гистограммы для каждого параметра.

# %% [markdown]
# #### Площадь

# %% [markdown]
# Посмотрим статистические характеристики столбца 'total_area'

# %%
df['total_area'].describe().T
# Out:
# count    20905.000000
# mean        60.509551
# std         34.490375
# min         14.000000
# 25%         40.500000
# 50%         52.100000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %%
df.boxplot(column='total_area', vert=False, figsize=(14,7))
plt.show()

# %% [markdown]
# Построим гистограмму

# %%
df['total_area'].hist(bins=50, range=(60,600),figsize=(14,3))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Явно в данных есть единичные выбросы, попробуем построить гистограмму отбросив редко встречающиеся значения.

# %%
df['total_area'].hist(bins=50, range=(14,100),figsize=(14,3));

# %% [markdown]
# На гистограмме видны три пика. Можно сделать вывод, что самая популярная площадь в районе 50 квадратных метра, далее по полуряности квартиры с площадью 43-45 квадратных метра и квартиры с площадью 35 квадратных метров. Данный метраж соответствует кваритре с одной или двумя комнатами. Распределение похоже на распределение Гаусса.

# %% [markdown]
# #### Цена

# %% [markdown]
# Посмотрим статистические характеристики столбца 'last_price'

# %%
pd.options.display.float_format = '{:,.1f}'.format
df['last_price'].describe().T
# Out:
# count        20,905.0
# mean      6,503,257.7
# std       9,603,551.2
# min          12,190.0
# 25%       3,500,000.0
# 50%       4,700,000.0
# 75%       6,800,000.0
# max     420,000,000.0
# Name: last_price, dtype: float64

# %%
df.boxplot(column='last_price',vert=False, figsize=(14,7))
plt.show()

# %%
df['last_price'].hist(bins=50,range=(0,10000000),figsize=(15,5));

# %% [markdown]
# На гистограмме виден пик по стоимости квартир  по цене около 3,8 -4,0 млн рублей. Распределение похоже на распределение Гаусса. В данных есть выбросы.

# %% [markdown]
# #### Число комнат

# %% [markdown]
# Посмотрим статистические характеристики столбца 'rooms'

# %%
df['rooms'].describe().T
# Out:
# count   20,905.0
# mean         2.1
# std          1.1
# min          1.0
# 25%          1.0
# 50%          2.0
# 75%          3.0
# max         19.0
# Name: rooms, dtype: float64

# %%
df.boxplot(column='rooms')
plt.show()

# %% [markdown]
# Построим гистограмму

# %%
df['rooms'].hist(bins=50, range=(1,19), figsize=(15,5));

# %% [markdown]
# Исходя из гистограммы можно сделать вывод, что популярные две категории квартир: с одной комнатой примерно 7000 объявлений, чуть больше 7000 обьявлений с двумя комнатами. Трехкомнатная квартира встречается с частотой чуть больше 5000. Четырехкомнатная встречается в 1000 объявлениях. Намного реже встречаются квартиры с 5,6 или 7 комнатами. Напращивается вывод, чем больше комнат, тем меньше квартир. Также есть максимальное значение - 19, которое является выбросом. От него мы избавимся в следующих пунктах данного проекта. Распределение данных похоже на распределение Пуассона.

# %% [markdown]
# #### Высота потолков

# %% [markdown]
# Посмотрим статистические характеристики столбца 'ceiling_height'

# %%
df['ceiling_height'].describe().T
# Out:
# count   20,905.0
# mean         2.7
# std          1.0
# min          1.0
# 25%          2.6
# 50%          2.6
# 75%          2.7
# max        100.0
# Name: ceiling_height, dtype: float64

# %%
df.boxplot(column='ceiling_height', vert=False, figsize=(14,7))
plt.show()

# %%
df['ceiling_height'].hist(bins=30, range=(1,19), figsize=(9,5));

# %% [markdown]
# Построим гистограмму без выбросов

# %%
df['ceiling_height'].hist(bins=30, range=(1,5), figsize=(9,5));

# %% [markdown]
# Исходя из гистограммы мы видим, что подавляющее количество квартир с высотой потолков 2,6-2,7 м. Остальные значения встречаются редко, что легко объяснить: нестандартная высота потолоков - редкость. Распределение похоже на распределение Пуассона

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Самая популярная площадь в объявлениях в районе 50 квадратных метров, далее по полуряности квартиры с площадью 43-45 квадратных метра и квартиры с площадью 35 квадратных метров. Пользователи размещают объявления чаще всего с ценой около 3,8 - 4,0 млн рублей. Большая частота объявлений встречается с одной комнатой и с двумя комнатами.

# %% [markdown]
# ### Изучение время продажи квартиры. Построение гистограммы. Расчет среднего и медианы. Описать, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %% [markdown]
# Посмотрим статистические характеристики столбца 'days_exposition'

# %%
df['days_exposition'].describe().T
# Out:
# count   20,905.0
# mean       159.9
# std        215.8
# min          0.0
# 25%         21.0
# 50%         78.0
# 75%        205.0
# max      1,580.0
# Name: days_exposition, dtype: float64

# %%
df['days_exposition'].hist(bins=50, range=(0,300), figsize=(9,5));

# %% [markdown]
# Но на этапе предообработки мы заменили пропски(объявления, которые еще не сняты с публикаци) на своеобразный "маркер" равный 0, вычислим медиану и среднее без данного "маркера".

# %%
df.query('days_exposition != 0')['days_exposition'].describe().T
# Out:
# count   18,020.0
# mean       185.5
# std        222.0
# min          1.0
# 25%         45.0
# 50%        102.0
# 75%        239.0
# max      1,580.0
# Name: days_exposition, dtype: float64

# %%
print('Медиана:', df.query('days_exposition != 0')['days_exposition'].median())
print('Cреднее:', df.query('days_exposition != 0')['days_exposition'].mean())
# Out:
# Медиана: 102.0
# Cреднее: 185.5110987791343

# %%
plt.hist(df.query('days_exposition != 0')['days_exposition'], bins=100, range=(0,100))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show();

# %%
plt.hist(df.query('days_exposition != 0')['days_exposition'], bins=150, range=(102,1500))
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show();

# %%
fig, axes = plt.subplots(1,2, figsize=(20,7))       

df.query('days_exposition != 0')['days_exposition'].hist(bins=100, range=(0,100),ax=axes[0])
axes[0].set_title('Распределение кол-ва квартир по времени продажи в диапозоне до 100 дней')
df.query('days_exposition != 0')['days_exposition'].hist(bins=150, range=(102,1500),ax=axes[1])
axes[1].set_title('Распределение кол-тва квартир по времени продажи в диапозоне от 100 дней')    
plt.show()

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Исходя из анализа гистограммы и статистических показателей:
# Медианное время продажи - 102 дня. Среднее время продажи - 185 дней.
# В основном квартиры продаются примерно за 100 дней.В данных присутсвуют объявления, где продали квариру за первые 10 дней, а есть наоброт с длительныи сроком публикации 500 дней и больше.
#
# Ориентируясь на значение 25% и 75% квартилей, можно утверждать, что быстрой продажей является продажа за 45 дней и быстрее. Медленной продажой является продажа за 205 дней и медленнее.

# %% [markdown]
# ##### Убираем редкие и выбивающиеся значения. Описание, какие особенности обнаружили.

# %% [markdown]
# Но основе изучения параметров (площадь, цена, число комнат, высота потолков) шагом ранее, Теперь я решила по отдельности удалять выбивающиеся значения из каждого столбца на основе разброса данных.

# %%
df[['last_price', 'total_area', 'ceiling_height', 'days_exposition', 'rooms']].describe()
# Out:
#          last_price  total_area  ceiling_height  days_exposition    rooms
# count      20,905.0    20,905.0        20,905.0         20,905.0 20,905.0
# mean    6,503,257.7        60.5             2.7            159.9      2.1
# std     9,603,551.2        34.5             1.0            215.8      1.1
# min        12,190.0        14.0             1.0              0.0      1.0
# 25%     3,500,000.0        40.5             2.6             21.0      1.0
# 50%     4,700,000.0        52.1             2.6             78.0      2.0
# 75%     6,800,000.0        70.0             2.7            205.0      3.0
# max   420,000,000.0       900.0           100.0          1,580.0     19.0

# %% [markdown]
# На предыдущем шаге мы на боксплоте видели в столбце "total_area" редко встречающиеся значения в районе 550-600 метров и 900.

# %% [markdown]
# Посмотрим теперь на распределение

# %%
df.query('total_area < 400').boxplot(column='total_area', vert=False, figsize=(14,7));

# %% [markdown]
# Распределение стало более менее равномерное.

# %% [markdown]
# В столбце 'last_price' сильно заметны выбивающиеся значения в ценовом сегменте больше 100 млн. Посмотрим на распределение данных без этих значений

# %%
df.query('last_price <= 100000000').boxplot(column='last_price', vert=False, figsize=(14,7));

# %% [markdown]
# Отлично, распределение цен стало более равномерным.

# %% [markdown]
# В столбце "ceiling_height" мы видим слишком маленькие значения 1 метр и максимальное значение 10 метров. Оставим в ДатаФрейме все, что между ними

# %%
df.query('1 < ceiling_height < 100').boxplot(column='ceiling_height', vert=False, figsize=(20,10));

# %% [markdown]
# Видим, что есть значения в диапозоне 20-30 м , скорее всего пользователь не поставил запятую и вместо высоты потолков от 2 до 3 метров получилось большое значение. Есть еще единичные выбросы в диапозоне от 5 до 10 метров.Попробуем их тоже исключить

# %%
df.query('1 < ceiling_height < 5').boxplot(column='ceiling_height', vert=False, figsize=(20,10));

# %% [markdown]
# Видим, что есть еще выбивающиеся значения в районе 1,5 метра - 2,5 метров а также несколько значений больше 4.5 метров. Преобразуем еще раз ДатаФрейм

# %%
df.query('2.5 <= ceiling_height <= 4.5').boxplot(column='ceiling_height', vert=False, figsize=(20,10));

# %% [markdown]
# Исходя из предыдущего шага на графике распредления данных по числу комнат единичные значения встречаются после значения 10 комнат. Выберем только значения меньше 10 комнат.

# %%
df.query('rooms <= 10').boxplot(column='rooms', vert=False, figsize=(20,10));

# %% [markdown]
# Остановимся на том, что максимальное количество комнат будет 10. Так как возможно продают бывшие коммуналки, как одну квартиру

# %%
df.boxplot(column='days_exposition', vert=False, figsize=(20,10));

# %% [markdown]
# В принципе данные распредлены более менее нормально, нет совсем выбивающихся значений, считаю нужным оставить данный столбец без изменений

# %%
df_filter = df.query('total_area < 400 and last_price <= 100000000 and ceiling_height >= 2.5 and ceiling_height <=4.5 and rooms <=10')

# %%
df_filter.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000       108.0           2019-03-07      3
# 1             7     3350000        40.4           2018-12-04      1
# 2            14     2995000        40.4           2018-10-22      1
# 3             1     2800000        40.4           2017-08-28      1
# 4            10     4250000        40.4           2018-11-12      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.7            16         51.0      8         False  ...
# 1             2.6            11         18.6      1         False  ...
# 2             2.6            10         18.6      4         False  ...
# 3             2.6            10         18.6      6         False  ...
# 4             2.6            10         18.6      2         False  ...
#
#    days_exposition  median_living_area  median_kitchen_area   m_price weekday  \
# ...

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20766 entries, 0 to 20904
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          20766 non-null  int64
#  1   last_price            20766 non-null  int64
#  2   total_area            20766 non-null  float64
#  3   first_day_exposition  20766 non-null  datetime64[ns]
#  4   rooms                 20766 non-null  int64
#  5   ceiling_height        20766 non-null  float64
#  6   floors_total          20766 non-null  int64
#  7   living_area           20766 non-null  float64
#  8   floor                 20766 non-null  int64
#  9   is_apartment          20766 non-null  bool
#  10  studio                20766 non-null  bool
#  11  open_plan             20766 non-null  bool
#  12  kitchen_area          20766 non-null  float64
#  13  balcony               20766 non-null  int64
#  14  locality_name         20766 non-null  object
# ...

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# С помощью боксплотов в предыдущем пункте проекта и статистических показателей выбранных столбцов 'last_price', 'total_area',  'days_exposition', 'ceiling_height', 'rooms' мы проанализирвоали распределения данных и в данных столбцах убрали выбивающиеся из распределения значения.
#
# Получили новую отфильтрованную таблицу df_filter с помощью метода query(). Теперь таблица содержит 20766 строк.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучить, зависит ли цена от площади, числа комнат, удалённости от центра. Изучить зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# Так как необходимо посмотреть зависимость от множества факторов для удобства напишем функцию, которая возвращает значение коэффициента коррелции и возвращает диаграмму рассеяния (scatter plot)

# %%
pd.plotting.scatter_matrix(df_filter[['last_price','total_area','city_centers_nearest']],figsize=(15, 15))
print('Таблица корреляции last_price - total_area - city_centers_nearest для df_filter')
print()
print(df_filter[['last_price','total_area','city_centers_nearest']].corr())
# Out:
# Таблица корреляции last_price - total_area - city_centers_nearest для df_filter
#
#                       last_price  total_area  city_centers_nearest
# last_price                   1.0         0.8                  -0.3
# total_area                   0.8         1.0                  -0.2
# city_centers_nearest        -0.3        -0.2                   1.0

# %% [markdown]
# Видна прямая сильная зависимость стоимости от общей площади квартиры, коэффициент корреляции равен 0,8. Также по графику видно, что при увеличении площади растет и цена.
#
# Зависимость между расстоянием до центра и ценой умеренная, обратная, коэффициент корреляции равен = (-0,3).чем меньше расстояние до центра, тем выше цена на недвижимость. На графике хорошо видно, что при приближении к центру цена увеличиапется, а при удалении от центра цена стремительно падает. Но связь довольно слабая так как для квартир, которые расположены очень далеко от центра, влияние этого параметра становится неважным, так как и так уже далеко.

# %%
df_filter.groupby('rooms')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(14,7), legend = True);

# %% [markdown]
# Из графика видно, что при увеличении количества комнат линейно возрастает и стоимость квартир. При значении комнат 7 уже не сильно прослеживается прямая сильная зависимости цены от количества комнат.

# %% [markdown]
# Коэффициент корреляции равен = - 0,35. Связь средняя обратня, что означет: чем меньше расстояние до центра, тем выше цена на недвижимость. На графике  хорошо видно, что при приближении к центру цена увеличиапется, а при удалении от центра цена стремительно падает.

# %%
#Вычислим среднюю цену в каждой категории
df_filter.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(10,5), legend = True);

# %% [markdown]
# На гистограмме видно, что первый этаж популярен менее всего и цены соответсвующие, цены ниже. Самый популярная категория этажей - другие, здесь самые высокие цены.

# %%
df_filter.groupby('weekday')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(10,5), legend = True);

# %% [markdown]
# Из графика видно, что минимальные средние цены в субботу и воскресенье, самые высокие - в понедельник и четверг

# %%
df_filter.groupby('month')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(10,5), legend = True);

# %% [markdown]
# Анализируя график можно сказать, что самая высокая стоимость в сентябре, ноябре и в декабре Самая низкая стоимость в октябре и весной в марте-апреле.

# %%
df_filter.groupby('year')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(10,5), legend = True);

# %% [markdown]
#  Исходя из графика видно что в 2014 году был пик высокой стоимости кварит видимо повлиял кризис на данный факт, с 2015 по 2018 вклчительно цены на жилье заметно падали, в 2019 году снова начался рост цен.

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Обнаружена сильная зависимость стоимости от общей площади квартиры, коэффициент корреляции равен 0,8, связь прямая.
# При взаимосвязи стоимости с расстоянием от центра обнаружено, что коэффициент корреляции равен = - 0,3. Связь незначительная обратня, что означет: чем меньше расстояние до центра, тем выше цена на недвижимость.  Первый этаж популярен менее всего и цены соответсвующие, цены ниже. Самый популярная категория этажей - другие, здесь самые высокие цены.
#
# Самая высокая стоимость квартиры наблюдается в понедельник и четверг в сентябре, ноябре и декабре. Самые высокие цены на рынке недвижимости были в 2014 году, далее был сильный спад и в 2019 начался снова рост цен.

# %% [markdown]
# ### Выбрать 10 населённых пунктов с наибольшим числом объявлений. Посчитать среднюю цену квадратного метра в этих населённых пунктах. Выделить населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %% [markdown]
# Cоздадим сводную таблицу с наименованием населенных пунктов, количеством объявлений и средней ценой за квадратный метр.

# %%
city_table = df_filter.pivot_table(index=['locality_name'], values= 'm_price', aggfunc =['count', 'mean'])
city_table.columns = ['count', 'mean_m_price']
city_table
# Out:
#                count  mean_m_price
# locality_name
# бокситогорск      10      16,910.9
# волосово          35      40,144.6
# волхов            89      35,077.3
# всеволожск       356      69,102.5
# выборг           188      58,441.5
# ...              ...           ...
# сосновый бор      67      76,122.3
# сясьстрой         11      32,891.7
# тихвин            35      39,557.5
# тосно             90      58,684.0
# шлиссельбург      55      58,412.9
#
# [310 rows x 2 columns]

# %% [markdown]
# Выделип топ10 населенных пунктов по количеству объявлений

# %%
top_10_cities = city_table.sort_values(by='count', ascending=False).head(10)
top_10_cities
# Out:
#                    count  mean_m_price
# locality_name
# санкт-петербург    13939     112,745.1
# посёлок мурино       429      85,412.8
# посёлок шушары       392      78,393.7
# всеволожск           356      69,102.5
# пушкин               335     103,322.3
# колпино              321      75,246.0
# гатчина              290      68,635.6
# посёлок парголово    287      90,791.5
# деревня кудрово      226      92,248.5
# петергоф             190      83,754.2

# %% [markdown]
# Отсортируем теперь по цене

# %%
top_10_cities = top_10_cities.sort_values(by='mean_m_price', ascending=False).head(10)
top_10_cities
# Out:
#                    count  mean_m_price
# locality_name
# санкт-петербург    13939     112,745.1
# пушкин               335     103,322.3
# деревня кудрово      226      92,248.5
# посёлок парголово    287      90,791.5
# посёлок мурино       429      85,412.8
# петергоф             190      83,754.2
# посёлок шушары       392      78,393.7
# колпино              321      75,246.0
# всеволожск           356      69,102.5
# гатчина              290      68,635.6

# %%
top_10_cities.plot.pie(y = 'count', figsize = (20,7));

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Мы виделили 10 населенных пунктов с наибольшим количеством объявлений. Из этих населенных пунктов самая высокая стоимость жилья в Санкт-Петербурге - средняя цена квадратного метра - 113916,8 руб, самая низкая стоимость жилья в Выборге - средняя цена квадратного метра - 58319,4 руб. Помимо этих двух городов в Топ10 входят: Пушкин, поселок Мурино, поселок Шушары, Всеволожск,  Колпино, поселок Парголово, Гатчина, деревня Кудрово.

# %% [markdown]
# ### Изучить предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделить квартиры в Санкт-Петербурге (locality_name). Задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.

# %% [markdown]
# Отфильтруем таблицу по городу - Санкт -Петербург

# %%
saint_pt_df = df_filter.query('locality_name == "санкт-петербург"')

# %%
saint_pt_df['city_centers_nearest_km'] = round(df['city_centers_nearest'] / 1000)

# %% [markdown]
# Создадим сводную таблицу с ценой и расстоянием в километрах

# %%
mean_km_spb = saint_pt_df.pivot_table(index='city_centers_nearest_km', values='last_price', aggfunc='mean') 
mean_km_spb.head()
# Out:
#                           last_price
# city_centers_nearest_km
# 0.0                     27,096,788.2
# 1.0                     15,724,315.1
# 2.0                     14,963,638.7
# 3.0                     10,785,157.8
# 4.0                     11,167,289.4

# %% [markdown]
# Теперь построим график на основе получившейся сводной таблицы

# %%
mean_km_spb.plot(grid=True, style='o-', xlim=(0,30), figsize=(20,7), legend = True)
plt.show()

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Исходя из гистограммы видно, что на расстоянии до 1 км от центра цена самая высокая.
# График резко падает в районе 2 и 8 км. Будем считать, все то, что является в диапозоне от 0 до 8 км является центальной зоной, а все до 2 км самым центром.
# На графике заметны пики в районе 20 и 28км, скорее всего там красивые парки, пруды, мало промышленных зон, поэтому и цена выше.

# %% [markdown]
# ### Выделить сегмент квартир в центре. Проанализировать эту территорию и изучить следующие параметры: площадь, цена, число комнат, высота потолков. Также выделить факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу

# %%
saint_pt_centr = saint_pt_df.query('city_centers_nearest_km <= 8')

# %%
fig, axes = plt.subplots(1,2, figsize=(20,7))       

saint_pt_centr['total_area'].hist(bins=50, range=(0,200),ax=axes[0])
axes[0].set_title('Распределение общей площади в центре Санкт-Петербурга')
saint_pt_df['total_area'].hist(bins=50, range=(0,200),ax=axes[1])
axes[1].set_title('Распределение общей площади во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# Исходя из графика видно, что чаще всего в центре квартиры имеют площадь в основном больше - 70-80 кв.м, когда во всем городе 45-50 кв.м

# %%
fig, axes = plt.subplots(1,2, figsize=(20,7))       

saint_pt_centr['last_price'].hist(bins=50, range=(4000000,40000000),ax=axes[0])
axes[0].set_title('Распределение цены в центре Санкт-Петербурга')
saint_pt_df['last_price'].hist(bins=50, range=(4000000,20000000),ax=axes[1])
axes[1].set_title('Распределение цены во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В центре чаще всего встречаются объявления с стоимостью квартир в диапозоне 8-12 млн,  по всему городу чаще встречаются квартиры со стоимостью 4-5млн руб.

# %%
fig, axes = plt.subplots(1,2, figsize=(20,7))       

saint_pt_centr['rooms'].hist(bins=50, range=(1,10),ax=axes[0])
axes[0].set_title('Распределение количества комнат в кваритирах в центре Санкт-Петербурга')
saint_pt_df['rooms'].hist(bins=50, range=(1,10),ax=axes[1])
axes[1].set_title('Распределение количества комнат в квартирах во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В центре объявления встречаются чаще с 2-ух комнатынми и 3-х комнатными квартирами. По всему городу чаще всего с 1-ой и с 2-мя комнатами.

# %%
fig, axes = plt.subplots(1,2, figsize=(20,7))       

saint_pt_centr['ceiling_height'].hist(bins=30, range=(2,5),ax=axes[0])
axes[0].set_title('Распределение высоты потолков в кваритирах в центре Санкт-Петербурга')
saint_pt_df['ceiling_height'].hist(bins=30, range=(2,5),ax=axes[1])
axes[1].set_title('Распределение высоты потолков в квартирах во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# Высота потолков 2,65-2,7 чаще всего встречается и в случае центральной части и в случае всего города. Но в центральной части есть еще небольшой пик с высотой потолков 3,1-3,2.

# %%
pd.plotting.scatter_matrix(saint_pt_centr[['last_price','city_centers_nearest']],figsize=(5, 5))
print('Таблица корреляции last_price - city_centers_nearest для центра Санкт-Петербурга')
print()
print(saint_pt_centr[['last_price','city_centers_nearest']].corr())
# Out:
# Таблица корреляции last_price - city_centers_nearest для центра Санкт-Петербурга
#
#                       last_price  city_centers_nearest
# last_price                   1.0                  -0.1
# city_centers_nearest        -0.1                   1.0

# %%
pd.plotting.scatter_matrix(saint_pt_df[['last_price','city_centers_nearest']],figsize=(5, 5))
print('Таблица корреляции last_price - city_centers_nearest для всего Санкт-Петербурга')
print()
print(saint_pt_df[['last_price','city_centers_nearest']].corr())
# Out:
# Таблица корреляции last_price - city_centers_nearest для всего Санкт-Петербурга
#
#                       last_price  city_centers_nearest
# last_price                   1.0                  -0.4
# city_centers_nearest        -0.4                   1.0

# %% [markdown]
# Зависисомость от удаленности от центра выше во всем городе(коэфф. кор  = (-0,4)): чем дальше от центра, тем отчетлевве видно снижение цен, когда в центра (коэфф. кор  = (-0,1)). Это связано с тем, что в центральной зоне цена плюс - минсус находится в одном диапозрне и не происходит резкого снижения.

# %%
df_filter.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(10,5), legend = True);

# %%
fig, axes = plt.subplots(1,2, figsize=(20,10))       

saint_pt_centr.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(20,7), legend = True, ax=axes[0])
axes[0].set_title('Зависимость цены от этажа в центре Санкт-Петербурга')
saint_pt_df.groupby('floor_group')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(20,7), legend = True, ax=axes[1])
axes[1].set_title('Зависимость цены от этажа во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В обоих случаях ниже всего цена для первого этажа, самая высокая цена в центре одинакова как для последнего этажа, так и для других этажей. Во всем городе выше цена для последних этажей.

# %%
fig, axes = plt.subplots(1,2, figsize=(20,10))       

saint_pt_centr.groupby('rooms')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(20,7), legend = True, ax=axes[0])
axes[0].set_title('Зависимость цены от числа комнат в центре Санкт-Петербурга')
saint_pt_df.groupby('rooms')['last_price'].agg('mean').plot(kind='bar', grid=True, figsize=(20,7), legend = True, ax=axes[1])
axes[1].set_title('Зависимость цены от числа комнат во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В обоих случаях видим, что цена растет с увеличением количества комнат с 1 по 5, но с 6 по 10 нет четкой зависимости по цене.

# %%
fig, axes = plt.subplots(1,2, figsize=(14,7))       

saint_pt_centr.groupby('weekday')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[0])
axes[0].set_title('Зависимость цены от дня размещения в центре Санкт-Петербурга')
saint_pt_df.groupby('weekday')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[1])
axes[1].set_title('Зависимость цены от дня размещения во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В центре публикуют объявления с наибольшой стоимостью в Воскресенье и в понедельник, с низкой стоимостью в среду и субботу.
# Во всем городе самы доргие квартиры публикуют в четверг, с низкой стоимостью в среду и субботу.

# %%
fig, axes = plt.subplots(1,2, figsize=(14,7))       

saint_pt_centr.groupby('month')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[0])
axes[0].set_title('Зависимость цены от месяца размещения в центре Санкт-Петербурга')
saint_pt_df.groupby('month')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[1])
axes[1].set_title('Зависимость цены от месяца размещения во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# В центре с наибольшей стоимостью публикуют в январе, феврале, декабре и ноябре. С низкой стоимостью в апреле и октябре.
# Во всем городе с наибольшей стоимостью публикуют в декабре-январе, с низкой стоимстью в октябре, апреле. Как и в центре.

# %%
fig, axes = plt.subplots(1,2, figsize=(14,7))       

saint_pt_centr.groupby('year')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[0])
axes[0].set_title('Зависимость цены от года размещения в центре Санкт-Петербурга')
saint_pt_df.groupby('year')['last_price'].agg('mean').plot(kind='line', style='o-', grid=True, figsize=(20,10), legend = True, ax=axes[1])
axes[1].set_title('Зависимость цены от года размещения во всем Санкт-Петербурге')    
plt.show()

# %% [markdown]
# Зависимость цены от года размещения, что в центре, что во всем городе - одинакова. Снижение стоимости вплоть до 2018 года, в 2019 году - рост.

# %% [markdown]
# #### Вывод по пункту

# %% [markdown]
# Выполнив сравнение, можно выдедить отличия:
#
# - В центре площадь квартир больше, чем во всем городе: чаще всего встречаются квартиры 70-80 кв.м в центре Санкт-Петербурга, а в городе 45-50 кв.м в.
# - В центре чаще всего встречаются объявления с большей стоимостью квартир (в диапозоне 8-12 млн), по всему городу чаще встречаются квартиры со стоимостью 4-5млн руб.
# - В центре объявления встречаются чаще с 2-ух комнатынми и 3-х комнатными квартирами. По всему городу чаще всего с 1-ой и с 2-мя комнатами.
# - Высота потолков 2,65-2,7 чаще всего встречается и в случае центральной части и в случае всего города. Но в центральной части есть достаточное количество квартир с высотой потолков в диапозоне от 3 до 3,5м.
# - Зависисомость от удаленности от центра выше во всем городе(коэфф. кор = (-0,4)): чем дальше от центра, тем отчетлевве видно снижение цен, когда в центра (коэфф. кор = (-0,1)).
# - В обоих случаях цена растет с увеличением количества комнат с 1 по 5, но с 6 по 10 нет четкой зависимости по цене.
# - В обоих случаях ниже всего цена для первого этажа, самая высокая цена в центре одинакова как для последнего этажа, так и для других этажей. Во всем городе выше цена для последних этажей.
# - В центре публикуют объявления с наибольшой стоимостью в Воскресенье и в понедельник. Во всем городе самые доргие квартиры публикуют в четверг. С низкой стоимостью в среду и субботу публикую обявления и в центре и во всем городе.
# - В центре с наибольшей стоимостью публикуют в январе, феврале, декабре и ноябре. Во всем городе с наибольшей стоимостью публикуют в декабре-январе. с низкой стоимстью публикую обявления и в центре и во всем городе в октябре, апреле.
# - Зависимость цены от года размещения, что в центре, что во всем городе - одинакова. Снижение стоимости вплоть до 2018 года, в 2019 году - рост.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для анализа был дан исходная таблица с данными из сервисами Яндекс.Недвижимость. Состоял исходный датафрейм из 22 колонок и 23699 строк.
#
# Предобработка
#
# - В ходе предообрабоки пропуски в стобцах 'floors_total' и 'locality_name'. В столбце 'ceiling_height' пропуски заменили медианным значением. В столбце 'balcony' заменили пропуски  на 0. В столбце "is_apartment" заполнили пропуски 0. Заменили пропуски в столбцах 'living_area','kitchen_area', воспользовавшись методом заполнения пропусков медианой с группировкой по нескольким переменным. В столбце 'city_centers_nearest' заменили пропуски в данном случае на 0, это будет своеобразным маркером для нас в ходе дальнейшей работы. Заменили пропуски на 0 в столбцах 'parks_around_3000', 'ponds_around_3000'. Пропуски в столбцах "airports_nearest", "parks_nearest", "ponds_nearest" не заменяли.
# - Изменили наименование столбцов cityCenters_nearest'на'city_centers_nearest','parks_around3000'на'parks_around_3000', 'ponds_around3000' на 'ponds_around_3000'.Столбец "first_day_exposition" приведен к типу datetime64.
# - Столбцы "floors_total", "last_price", "balcony" приведены к типу int64. Столбец 'is_apartment' приведен к типу bool. Колонки "airports_nearest", "cityCenters_nearest", "parks_around3000", "parks_nearest", "ponds_around3000", "ponds_nearest" оставили с типом float. В столбце 'locality_name' заменили в словах строки "е" на "ё".
# - В ходе предобработки в датафрейме осталось 20905 строк.
#
# Расчеты и добавление резултатов в таблицу
#
# - По заданию было добавлено в исходный датафрейм 7 столбцов, в которых были подсчитаны дополнительные параметры: цена квадратного метра; день недели, месяц и год публикации объявления; этаж квартиры; варианты — первый, последний, другой; соотношение жилой и общей площади, а также отношение площади кухни к общей.
#
# Исследовательский анализ данных
#
# - Самая популярная площадь в объявлениях в районе 50 квадратных метров, далее по полуряности квартиры с площадью 43-45 квадратных метра и квартиры с площадью 35 квадратных метров. Пользователи размещают объявления чаще всего с ценой около 3,8 - 4,0 млн рублей. Большая частота объявлений встречается с одной комнатой и с двумя комнатами.
#
# - Медианное время продажи - 102 дня. Среднее время продажи - 185 дней. Быстрой продажей является продажа за 45 дней и быстрее. Медленной продажой является продажа за 205 дней и медленнее.
#
# - В столбцах 'last_price', 'total_area',  'days_exposition', 'ceiling_height', 'rooms' мы убрали выбивающиеся из распределения значения с помощью метода query(). Получили новую отфильтрованную таблицу df_filter с помощью метода query(). Теперь таблица содержит 20766 строк.
#
# - Обнаружена сильная зависимость стоимости от общей площади квартиры, коэффициент корреляции равен 0,8, связь прямая.
# При взаимосвязи стоимости с расстоянием от центра обнаружено, что коэффициент корреляции равен = - 0,3. Связь незначительная обратня, что означет: чем меньше расстояние до центра, тем выше цена на недвижимость.  Первый этаж популярен менее всего и цены соответсвующие, цены ниже. Самый популярная категория этажей - другие, здесь самые высокие цены. Самая высокая стоимость квартиры наблюдается в понедельник и четверг в сентябре, ноябре и декабре. Самые высокие цены на рынке недвижимости были в 2014 году, далее был сильный спад и в 2019 начался снова рост цен.
#
# - Мы виделили 10 населенных пунктов с наибольшим количеством объявлений. Из этих населенных пунктов самая высокая стоимость жилья в Санкт-Петербурге, самая низкая стоимость жилья в Выборге. Выделен диапозон центральной зоны от 0 до 8 км.
#
# Выполнив сравнение данных в центре города Санкт - Петербурге и в самом городе, было выявлено:
# - В центре площадь квартир больше, чем во всем городе: чаще всего встречаются квартиры 70-80 кв.м в центре Санкт-Петербурга, а в городе 45-50 кв.м в.
# - В центре чаще всего встречаются объявления с большей стоимостью квартир (в диапозоне 8-12 млн), по всему городу чаще встречаются квартиры со стоимостью 4-5млн руб.
# - В центре объявления встречаются чаще с 2-ух комнатынми и 3-х комнатными квартирами. По всему городу чаще всего с 1-ой и с 2-мя комнатами.
# - Высота потолков 2,65-2,7 чаще всего встречается и в случае центральной части и в случае всего города. Но в центральной части есть достаточное количество квартир с высотой потолков в диапозоне от 3 до 3,5м.
# - Зависисомость от удаленности от центра выше во всем городе(коэфф. кор = (-0,4)): чем дальше от центра, тем отчетлевве видно снижение цен, когда в центра (коэфф. кор = (-0,1)).
# - В обоих случаях цена растет с увеличением количества комнат с 1 по 5, но с 6 по 10 нет четкой зависимости по цене.
# - В обоих случаях ниже всего цена для первого этажа, самая высокая цена в центре одинакова как для последнего этажа, так и для других этажей. Во всем городе выше цена для последних этажей.
# - В центре публикуют объявления с наибольшой стоимостью в Воскресенье и в понедельник. Во всем городе самые доргие квартиры публикуют в четверг. С низкой стоимостью в среду и субботу публикую обявления и в центре и во всем городе.
# - В центре с наибольшей стоимостью публикуют в январе, феврале, декабре и ноябре. Во всем городе с наибольшей стоимостью публикуют в декабре-январе. с низкой стоимстью публикую обявления и в центре и во всем городе в октябре, апреле.
# - Зависимость цены от года размещения, что в центре, что во всем городе - одинакова. Снижение стоимости вплоть до 2018 года, в 2019 году - рост.
